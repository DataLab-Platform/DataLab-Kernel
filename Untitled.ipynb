# %%
# Pre-configured namespace
workspace.list()
img = workspace.get("i001")
plotter.plot(img)
workspace.save("analysis.h5")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 3
#       1 # Pre-configured namespace
#       2 workspace.list()
# ----> 3 img = workspace.get("i001")
#       4 plotter.plot(img)
#       5 workspace.save("analysis.h5")
#
# File C:\Dev\DataLab-Kernel\datalab_kernel\workspace.py:569, in Workspace.get(self, name)
#     557 def get(self, name: str) -> DataObject:
#     558     """Retrieve an object by name.
#     559
#     560     Args:
#    (...)    567         KeyError: If object not found
#     568     """
# --> 569     return self._backend.get(name)
#
# File C:\Dev\DataLab-Kernel\datalab_kernel\workspace.py:104, in StandaloneBackend.get(self, name)
#     102 if name not in self._objects:
#     103     available = ", ".join(self._objects.keys()) if self._objects else "(empty)"
# --> 104     raise KeyError(
# ...
